# %%
# 1. Defining Functions
# 1. Write a function greet() that prints "Hello, Python Learner!" when called.
# 2. Write a square(num) that returns the square of a given number. Test is with different numbers.

def greet():
    print("Hello, Python Learner!")

greet()
# Out:
# Hello, Python Learner!

# %%
def square(num):
    return num ** 2

print(square(4))  # Output: 16
print(square(7))  # Output: 49
# Out:
# 16
# 49

# %%
#2. Function Arguments & Return Values
# 1. Write a function full_name(first, last) that takes first name and last name as parameters and returns a single in the format "first Last".
# 2. Write a function calculate_area(length, width=10) that returns the area of a rectangle Test it by Calling the function with:
#   1. Both length and width.
#   2. Only length (use default width).

def full_name(first, last):
    return f"{first} {last}"

print(full_name("John", "Doe"))  # Output: John Doe
print(full_name("Jane", "Smith"))  # Output: Jane Smith
# Out:
# John Doe
# Jane Smith

# %%
def calculate_area(length, width=10):
    return length * width

print(calculate_area(5, 3))  # Output: 15
print(calculate_area(5))     # Output: 50 (uses default width of
# Out:
# 15
# 50

# %%
# 3. Lambda Functions
# 1. Write a lambda function that adds two numbers and test id
# 2. Create a list [1,2,3,4,5] and use map() with a lambda function to their squares.

add = lambda x, y: x + y
print(add(5, 3))  # Output: 8
print(add(10, 15))  # Output: 25
# Out:
# 8
# 25

# %%
numbers = [1, 2, 3, 4, 5]
squared_numbers = list(map(lambda x: x ** 2, numbers))
print(squared_numbers)  # Output: [1, 4, 9, 16, 25]
# Out:
# [1, 4, 9, 16, 25]

# %%
# 4. Recuresion in Python
# 1. Write a recursive function factorial(n) that returns the factorial of a given number
# 2. Write a recursive function sum_of_digits(n) that returns the sum of the digits of a given number.

def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)
    
print(factorial(5))  # Output: 120
print(factorial(0))  # Output: 1
print(factorial(1))  # Output: 1
# Out:
# 120
# 1
# 1

# %%
def sum_of_digits(n):
    if n == 0:
        return 0
    else:
        return (n % 10) + sum_of_digits(n // 10)
    
print(sum_of_digits(123))  # Output: 6
print(sum_of_digits(4567))  # Output: 22
# Out:
# 6
# 22

# %%
# Modules and Pip - Using external Libraries
# 1. Import the math module and use it to :
#   1. Calculate the square root of 144.
#   2. Calculate sin(90) (hint: use math.radian())
# 2. Install and import the request module(if available) and use it to make a get request to "https://api.github.com" and print the status code of the response.


import math
print(math.sqrt(144))  # Output: 12.0
print(math.sin(math.radians(90)))  # Output: 1.0
# Out:
# 12.0
# 1.0

# %%
import requests
response = requests.get("https://api.github.com")
print(response.status_code)  # Output: 200 (or other status code depending on the
print(response.json())  # Output: JSON response from GitHub API
# Out:
# 200
# ...

# %%
# Write a function safe_divide(a, b) that returns the result of a divided by b. If b is zero, return "Cannot divide by zero" instead.
# Create a small module my_utils.py with a function is_even(num) that returns True if n is even. Import and use it in another Python file.

def safe_divide(a, b):
    if b == 0:
        return "Cannot divide by zero"
    else:
        return a / b
    
print(safe_divide(10, 2))  # Output: 5.0
print(safe_divide(10, 0))  # Output: Cannot divide by zero
# Out:
# 5.0
# Cannot divide by zero

# %%
def is_even(num):
    return num % 2 == 0 

print(is_even(4))  # Output: True
print(is_even(7))  # Output: False
# Out:
# True
# False
